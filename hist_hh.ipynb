# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("RNGWHHDd.xls", sheet_name = "Data 1")
data.drop([0, 1], inplace = True)

# %% [markdown]
# #### Visualizing Data

# %%
X = data.iloc[:,0]
y = data.iloc[:,1]
plt.figure(figsize = (20, 5))
plt.plot(X, y)

# %%
data = data.rename(columns={"Back to Contents": "Date", "Data 1: Henry Hub Natural Gas Spot Price (Dollars per Million Btu)": "Spot"})
# Out:
# 3.82

# %% [markdown]
# #### Defining Returns

# %%
def returns(data):
    returns = ()
    P_0 = data["Spot"][2]
    
    return returns

# %%
def historical_var(returns, confidence_level = .99):
